# %% [markdown]
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 1. ФАКТОРНЫЙ АНАЛИЗ
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Корреляция факторов с выручкой
# # - Random Forest Feature Importance
# # - Что сильнее всего влияет на продажи?
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 2. ПРОГНОЗ ПРОДАЖ (FORECAST)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Подготовка данных для Prophet
# # - Прогноз на 3-6 месяцев
# # - Доверительные интервалы (80-95%)
# # - Визуализация прогноза + компоненты (тренд, сезонность)
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 3. ПРОГНОЗ ОТТОКА
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Подготовка признаков (Recency, Frequency, Monetary)
# # - Логистическая регрессия
# # - Кто из клиентов уйдёт в следующем месяце?
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 4. WHAT-IF АНАЛИЗ (СЦЕНАРНОЕ МОДЕЛИРОВАНИЕ)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Сценарий 1: Рост цены на 10%
# # - Сценарий 2: Падение спроса на 15% (кризис)
# # - Сценарий 3: Рост клиентов на 20%
# # - Интерактивный what-if (слайдеры)
# # - Сравнение сценариев (таблица + график)

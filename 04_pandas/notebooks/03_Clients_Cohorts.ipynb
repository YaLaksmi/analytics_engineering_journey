# %% [markdown]
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 1. RFM-СЕГМЕНТАЦИЯ (КЛИЕНТЫ)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Recency, Frequency, Monetary
# # - 5 сегментов: Champions, Loyal, At Risk, New, Lost
# # - Распределение клиентов по сегментам
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 2. КОГОРТНЫЙ АНАЛИЗ
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Матрица удержания (проценты)
# # - Тепловая карта
# # - Retention Rate по когортам
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 3. LTV ПО КОГОРТАМ (НОВОЕ)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - LTV (Lifetime Value) для каждой когорты
# # - Сравнение LTV между когортами
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 4. АНАЛИЗ ОТТОКА (НОВОЕ)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Когда уходят клиенты? (после какой покупки)
# # - Распределение клиентов по частоте покупок

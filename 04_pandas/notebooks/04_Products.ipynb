# %% [markdown]
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 1. ТОП-10 ТОВАРОВ
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - По выручке
# # - По количеству продаж
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 2. ДИНАМИКА ТОП-10 ПО МЕСЯЦАМ
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Как меняется топ-10 в течение года
# # - Товары-лидеры по сезонам
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 3. СЕЗОННОСТЬ ТОВАРОВ (УГЛУБЛЁННО)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Какие товары растут в декабре?
# # - А какие в апреле?
#
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # 4. MARKET BASKET ANALYSIS (НОВОЕ)
# # : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# # - Что покупают вместе?
# # - Рекомендации для cross-selling
